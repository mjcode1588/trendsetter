# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import math
from sklearn.multioutput import MultiOutputRegressor

# %%
train_df = pd.read_csv('./train.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\Desktop\자율주행안테나\basecode.ipynb 셀 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89%EC%95%88%ED%85%8C%EB%82%98/basecode.ipynb#ch0000001?line=0'>1</a> train_df = pd.read_csv('./train.csv')
#
# NameError: name 'pd' is not defined

# %%
train_x = train_df.filter(regex='X') # Input : X Featrue
train_y = train_df.filter(regex='Y') # Output : Y Feature

# %%
rf_run = RandomForestRegressor(random_state=0, max_depth=5, min_samples_leaf=8, min_samples_split=8,n_estimators=200)
MultiOutputRegressor(rf_run).fit(train_x, train_y)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(max_depth=5,
#                                                      min_samples_leaf=8,
#                                                      min_samples_split=8,
#                                                      n_estimators=200,
#                                                      random_state=0))

# %%
LR = MultiOutputRegressor(rf_run).fit(train_x, train_y)

# %%
train_predict = LR.predict(train_x)
print("RMSE':{}".format(math.sqrt(mean_squared_error(train_predict, train_y))) )
# Out:
# RMSE':1.1904778063794281

# %%
test_df = pd.read_csv('./test.csv')

# %%
test_x = test_df.filter(regex='X')
test_y = test_df.filter(regex='Y')

# %%
test_predict = LR.predict(test_x)

# print("RMSE':{}".format(math.sqrt(mean_squared_error(train_predict, train_y))) )

# %%
submit = pd.read_csv('./sample_submission.csv')

# %%
for idx, col in enumerate(submit.columns):
    if col=='ID':
        continue
    submit[col] = test_predict[:,idx-1]
print('Done.')
# Out:
# Done.

# %%
submit.to_csv('./submit_rf1.csv', index=False)

# %%
import matplotlib.pyplot as plt # 득점모델 변수 중요도
import seaborn as sns
# %matplotlib inline
 
ftr_importances_values = LR.feature_importances
ftr_importances = pd.Series(ftr_importances_values, index=train_x.columns)
ftr_top = ftr_importances.sort_values(ascending=False)[:20]
 
plt.figure(figsize=(8, 6))
sns.barplot(x=ftr_top, y=ftr_top.index)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\자율주행안테나\basecode.ipynb 셀 15 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89%EC%95%88%ED%85%8C%EB%82%98/basecode.ipynb#ch0000013?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89%EC%95%88%ED%85%8C%EB%82%98/basecode.ipynb#ch0000013?line=2'>3</a> get_ipython().run_line_magic('matplotlib', 'inline')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89%EC%95%88%ED%85%8C%EB%82%98/basecode.ipynb#ch0000013?line=4'>5</a> ftr_importances_values = LR.feature_importances_
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89%EC%95%88%ED%85%8C%EB%82%98/basecode.ipynb#ch0000013?line=5'>6</a> ftr_importances = pd.Series(ftr_importances_values, index=train_x.columns)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89%EC%95%88%ED%85%8C%EB%82%98/basecode.ipynb#ch0000013?line=6'>7</a> ftr_top = ftr_importances.sort_values(ascending=False)[:20]
#
# AttributeError: 'MultiOutputRegressor' object has no attribute 'feature_importances_'
